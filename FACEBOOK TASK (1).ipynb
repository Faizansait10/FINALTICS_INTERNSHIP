# %% [markdown]
# #### FACEBOOK TASK 1

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("D:\\Users\\Faizan Sait\\Desktop\\Facebook_Marketplace_data.csv")
df
# Out:
#       status_id status_type status_published  num_reactions  num_comments  \
# 0             1       video   4/22/2018 6:00            529           512
# 1             2       photo  4/21/2018 22:45            150             0
# 2             3       video   4/21/2018 6:17            227           236
# 3             4       photo   4/21/2018 2:29            111             0
# 4             5       photo   4/18/2018 3:22            213             0
# ...         ...         ...              ...            ...           ...
# 7045       7046       photo   9/24/2016 2:58             89             0
# 7046       7047       photo  9/23/2016 11:19             16             0
# 7047       7048       photo  9/21/2016 23:03              2             0
# 7048       7049       photo   9/20/2016 0:43            351            12
# 7049       7050       photo  9/10/2016 10:30             17             0
#
#       num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         7050 non-null   int64
#  1   status_type       7050 non-null   object
#  2   status_published  7050 non-null   object
#  3   num_reactions     7050 non-null   int64
#  4   num_comments      7050 non-null   int64
#  5   num_shares        7050 non-null   int64
#  6   num_likes         7050 non-null   int64
#  7   num_loves         7050 non-null   int64
#  8   num_wows          7050 non-null   int64
#  9   num_hahas         7050 non-null   int64
#  10  num_sads          7050 non-null   int64
#  11  num_angrys        7050 non-null   int64
#  12  Column1           0 non-null      float64
#  13  Column2           0 non-null      float64
#  14  Column3           0 non-null      float64
#  15  Column4           0 non-null      float64
# ...

# %%
df.head()
# Out:
#    status_id status_type status_published  num_reactions  num_comments  \
# 0          1       video   4/22/2018 6:00            529           512
# 1          2       photo  4/21/2018 22:45            150             0
# 2          3       video   4/21/2018 6:17            227           236
# 3          4       photo   4/21/2018 2:29            111             0
# 4          5       photo   4/18/2018 3:22            213             0
#
#    num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  \
# 0         262        432         92         3          1         1
# 1           0        150          0         0          0         0
# 2          57        204         21         1          1         0
# 3           0        111          0         0          0         0
# 4           0        204          9         0          0         0
#
#    num_angrys  Column1  Column2  Column3  Column4
# 0           0      NaN      NaN      NaN      NaN
# ...

# %%
df.isnull().sum()
# Out:
# status_id              0
# status_type            0
# status_published       0
# num_reactions          0
# num_comments           0
# num_shares             0
# num_likes              0
# num_loves              0
# num_wows               0
# num_hahas              0
# num_sads               0
# num_angrys             0
# Column1             7050
# Column2             7050
# Column3             7050
# Column4             7050
# dtype: int64

# %%
df.describe()
# Out:
#          status_id  num_reactions  num_comments   num_shares    num_likes  \
# count  7050.000000    7050.000000   7050.000000  7050.000000  7050.000000
# mean   3525.500000     230.117163    224.356028    40.022553   215.043121
# std    2035.304031     462.625309    889.636820   131.599965   449.472357
# min       1.000000       0.000000      0.000000     0.000000     0.000000
# 25%    1763.250000      17.000000      0.000000     0.000000    17.000000
# 50%    3525.500000      59.500000      4.000000     0.000000    58.000000
# 75%    5287.750000     219.000000     23.000000     4.000000   184.750000
# max    7050.000000    4710.000000  20990.000000  3424.000000  4710.000000
#
#          num_loves     num_wows    num_hahas     num_sads   num_angrys  \
# count  7050.000000  7050.000000  7050.000000  7050.000000  7050.000000
# mean     12.728652     1.289362     0.696454     0.243688     0.113191
# std      39.972930     8.719650     3.957183     1.597156     0.726812
# ...

# %% [markdown]
# ### Question 1: How does the time of upload (status_published) affect num_reaction?

# %%
df.head()
# Out:
#    status_id status_type status_published  num_reactions  num_comments  \
# 0          1       video   4/22/2018 6:00            529           512
# 1          2       photo  4/21/2018 22:45            150             0
# 2          3       video   4/21/2018 6:17            227           236
# 3          4       photo   4/21/2018 2:29            111             0
# 4          5       photo   4/18/2018 3:22            213             0
#
#    num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  \
# 0         262        432         92         3          1         1
# 1           0        150          0         0          0         0
# 2          57        204         21         1          1         0
# 3           0        111          0         0          0         0
# 4           0        204          9         0          0         0
#
#    num_angrys  Column1  Column2  Column3  Column4
# 0           0      NaN      NaN      NaN      NaN
# ...

# %%
df['status_published']=pd.to_datetime(df['status_published'])
df.head()
# Out:
#    status_id status_type    status_published  num_reactions  num_comments  \
# 0          1       video 2018-04-22 06:00:00            529           512
# 1          2       photo 2018-04-21 22:45:00            150             0
# 2          3       video 2018-04-21 06:17:00            227           236
# 3          4       photo 2018-04-21 02:29:00            111             0
# 4          5       photo 2018-04-18 03:22:00            213             0
#
#    num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  \
# 0         262        432         92         3          1         1
# 1           0        150          0         0          0         0
# 2          57        204         21         1          1         0
# 3           0        111          0         0          0         0
# 4           0        204          9         0          0         0
#
#    num_angrys  Column1  Column2  Column3  Column4
# 0           0      NaN      NaN      NaN      NaN
# ...

# %%
# Extract the hour of the day the post was published
df['publish_hour'] = df['status_published'].dt.hour #.dt is accessor to access the datetime
#specific functionalities
df['publish_hour'].head()
df.head()
# Out:
#    status_id status_type    status_published  num_reactions  num_comments  \
# 0          1       video 2018-04-22 06:00:00            529           512
# 1          2       photo 2018-04-21 22:45:00            150             0
# 2          3       video 2018-04-21 06:17:00            227           236
# 3          4       photo 2018-04-21 02:29:00            111             0
# 4          5       photo 2018-04-18 03:22:00            213             0
#
#    num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  \
# 0         262        432         92         3          1         1
# 1           0        150          0         0          0         0
# 2          57        204         21         1          1         0
# 3           0        111          0         0          0         0
# 4           0        204          9         0          0         0
#
#    num_angrys  Column1  Column2  Column3  Column4  publish_hour
# ...

# %%
# Extract the day of the week (Monday=0, Tuesday=1, ..., Sunday=6)
df['publish_day_of_week'] = df['status_published'].dt.dayofweek
df['publish_day_of_week'].head()
df.head()
# Out:
#    status_id status_type    status_published  num_reactions  num_comments  \
# 0          1       video 2018-04-22 06:00:00            529           512
# 1          2       photo 2018-04-21 22:45:00            150             0
# 2          3       video 2018-04-21 06:17:00            227           236
# 3          4       photo 2018-04-21 02:29:00            111             0
# 4          5       photo 2018-04-18 03:22:00            213             0
#
#    num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  \
# 0         262        432         92         3          1         1
# 1           0        150          0         0          0         0
# 2          57        204         21         1          1         0
# 3           0        111          0         0          0         0
# 4           0        204          9         0          0         0
#
#    num_angrys  Column1  Column2  Column3  Column4  publish_hour  \
# ...

# %%
#extract the month of the year the post was pulished
df['publish_month']=df['status_published'].dt.month
df.head() #1-->jan 2-->feb ....12-->decemebr
# Out:
#    status_id status_type    status_published  num_reactions  num_comments  \
# 0          1       video 2018-04-22 06:00:00            529           512
# 1          2       photo 2018-04-21 22:45:00            150             0
# 2          3       video 2018-04-21 06:17:00            227           236
# 3          4       photo 2018-04-21 02:29:00            111             0
# 4          5       photo 2018-04-18 03:22:00            213             0
#
#    num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  \
# 0         262        432         92         3          1         1
# 1           0        150          0         0          0         0
# 2          57        204         21         1          1         0
# 3           0        111          0         0          0         0
# 4           0        204          9         0          0         0
#
#    num_angrys  Column1  Column2  Column3  Column4  publish_hour  \
# ...

# %%
# Let's see the first few rows of the DataFrame with the new features
print("\nDataFrame with extracted time features:")
df[['status_published', 'publish_hour', 'publish_day_of_week', 'publish_month']].head()
# Out:
# DataFrame with extracted time features:
#      status_published  publish_hour  publish_day_of_week  publish_month
# 0 2018-04-22 06:00:00             6                    6              4
# 1 2018-04-21 22:45:00            22                    5              4
# 2 2018-04-21 06:17:00             6                    5              4
# 3 2018-04-21 02:29:00             2                    5              4
# 4 2018-04-18 03:22:00             3                    2              4

# %%
columns_drop=['Column1','Column2','Column3','Column4']
df=df.drop(columns=columns_drop)

# %%
df[['status_published', 'publish_hour', 'publish_day_of_week', 'publish_month','num_reactions']].head()
# Out:
#      status_published  publish_hour  publish_day_of_week  publish_month  \
# 0 2018-04-22 06:00:00             6                    6              4
# 1 2018-04-21 22:45:00            22                    5              4
# 2 2018-04-21 06:17:00             6                    5              4
# 3 2018-04-21 02:29:00             2                    5              4
# 4 2018-04-18 03:22:00             3                    2              4
#
#    num_reactions
# 0            529
# 1            150
# 2            227
# 3            111
# 4            213

# %% [markdown]
# #### Why extract these specific features?
#
# ##### Hour of the Day: User activity on social media platforms often varies throughout the day. We want to see if posts published at certain times (e.g., peak usage hours) tend to receive more reactions.
# ##### Day of the Week: Engagement might also differ based on the day of the week. For example, weekend posts might have different interaction patterns than weekday posts.
# ##### Month of the Year: There could be seasonal trends or specific events during certain months that influence engagement.

# %%
df[['status_published', 'publish_hour', 'publish_day_of_week', 'publish_month','num_reactions']].head()
# Out:
#      status_published  publish_hour  publish_day_of_week  publish_month  \
# 0 2018-04-22 06:00:00             6                    6              4
# 1 2018-04-21 22:45:00            22                    5              4
# 2 2018-04-21 06:17:00             6                    5              4
# 3 2018-04-21 02:29:00             2                    5              4
# 4 2018-04-18 03:22:00             3                    2              4
#
#    num_reactions
# 0            529
# 1            150
# 2            227
# 3            111
# 4            213

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#WE HAVE TO FIND THE RELATIONSHIP BETWEEN STATUS_pUBLISHED AND NUM_REACTIONS USING
# publish_day_of_week , publish_month , publish_hour

# %%
#for plotting the average reactions per hour of the day
average_reactions_by_hour = df.groupby('publish_hour')['num_reactions'].mean().sort_index()
print(average_reactions_by_hour)
# Out:
# publish_hour
# 0     261.839474
# 1     203.315725
# 2     163.907618
# 3     290.270208
# 4     242.685864
# 5     293.870968
# 6     340.213198
# 7     183.301549
# 8     204.796897
# 9     205.780761
# 10    234.508333
# 11    180.639456
# 12    196.053763
# 13    176.875000
# 14    261.333333
# 15    341.666667
# 16    283.250000
# 17    384.000000
# 18    351.750000
# 19    442.368421
# 20    417.288136
# 21    261.907895
# 22    238.376126
# 23    244.276850
# Name: num_reactions, dtype: float64

# %%
#PLOTTING GRAPH FOR AVERAGE REACTIONS PER HOUR OF THE DAY
plt.figure(figsize=(10,6))
average_reactions_by_hour.plot(kind='line',marker='o')
plt.title("Average number of reactions by hour of the day")
plt.xlabel("hour of the day(0-23)")
plt.ylabel("Average number of reactions")
plt.grid(True)
plt.xticks(range(24))
plt.show()

#AT 19 WHICH IS AT 7 PM THE REACTIONS WERE ALL TIME HIGH
#AT 2 WHICH IS AT 2 AM THE REACTIONS WERE THE LEASTT

# %%
#PLOTTING THE GRAPH FOR AVERAGE REACTIONS PER DAY OF THE WEEK 
days =  ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
average_reactions_by_day = df.groupby('publish_day_of_week')['num_reactions'].mean().reindex(range(7))
average_reactions_by_day.index = days
print(average_reactions_by_day)

#PLOTTING GRAPH FOR AVERAGE REACTIONS PER day OF THE WEEK
plt.figure(figsize=(10,6))
average_reactions_by_day.plot(kind='line',marker='o')
plt.title("Average number of reactions per day of the week ")
plt.xlabel("Days of the week (Monday - sunday)")
plt.ylabel("Average number of reactions")
plt.grid(True)
plt.xticks(range(7))
plt.xticks(rotation=45)
plt.show()
# Out:
# Monday       207.198189
# Tuesday      197.299712
# Wednesday    245.386340
# Thursday     262.702950
# Friday       232.355446
# Saturday     233.209776
# Sunday       234.494806
# Name: num_reactions, dtype: float64

# %%
#Analyze average reactions by month of the year (Jan - Dec)
months =  ['January', 'february', 'March', 'April', 'May', 'June', 'July','August','September',
          'October','November','December']
average_reactions_by_month = df.groupby('publish_month')['num_reactions'].mean().reindex(range(12))
average_reactions_by_month.index = months
print(average_reactions_by_month)

#PLOTTING GRAPH FOR AVERAGE REACTIONS PER Month OF THE WEEK
plt.figure(figsize=(10,6))
average_reactions_by_month.plot(kind='line',marker='o')
plt.title("Average number of reactions per Month of the Year ")
plt.xlabel("Months of the year (January - December)")
plt.ylabel("Average number of reactions")
plt.grid(True)
plt.xticks(range(12))
plt.xticks(rotation=45)
plt.show()


#MAY WAS THE HIGHEST AVERAGEG NUMBER OF REACTIONS FOR THE MONTH OF THE TERA
# Out:
# January             NaN
# february     230.579487
# March        220.651072
# April        314.286787
# May          350.822047
# June         304.652115
# July         263.246689
# August       190.835735
# September    185.937876
# October      204.462963
# November     256.373196
# December     134.462908
# Name: num_reactions, dtype: float64

# %% [markdown]
# ##### The time of upload (status_published) appears to have a noticeable impact on the number of reactions. On average, posts published around 7 PM (19:00) tend to receive the highest number of reactions, likely due to peak user activity during evening leisure time. In terms of the day of the week,
# ##### Thursday shows the highest average engagement, possibly indicating mid-week momentum or specific posting strategies.
# ##### Finally, May stands out as the month with the highest average number of reactions, which could be attributed to seasonal trends, content focus, or marketing campaigns.
# ##### Further analysis of the distribution and volume of posts during these peak times could provide a more comprehensive understanding

# %% [markdown]
# ### QUESTION 2
# #### Is there a correlation between the number of reactions (num_reactions) and other engagement metrics
# #### such as comments (num_comments) and shares (num_shares)? If so, what is the strength and direction of this correlation?

# %%
df[['num_reactions','num_comments','num_shares']].head()
# Out:
#    num_reactions  num_comments  num_shares
# 0            529           512         262
# 1            150             0           0
# 2            227           236          57
# 3            111             0           0
# 4            213             0           0

# %%
correlation_columns = ['num_reactions', 'num_comments', 'num_shares']
correlation_data = df[correlation_columns].copy()
correlation_data.head()
# Out:
#    num_reactions  num_comments  num_shares
# 0            529           512         262
# 1            150             0           0
# 2            227           236          57
# 3            111             0           0
# 4            213             0           0

# %%
correlation_matrix = correlation_data.corr()
correlation_matrix

#+1: Indicates a perfect positive linear relationship (as one variable increases, the other increases proportionally).
#-1: Indicates a perfect negative linear relationship (as one variable increases, the other decreases proportionally).
#0: Indicates no linear relationship between the variables.
# Out:
#                num_reactions  num_comments  num_shares
# num_reactions       1.000000      0.150843    0.250723
# num_comments        0.150843      1.000000    0.640637
# num_shares          0.250723      0.640637    1.000000

# %% [markdown]
# #####  Correlation between num_reactions and num_comments: Coefficient: 0.150843 [WEAK]
# #####  Correlation between num_reactions and num_shares: Coefficient: 0.250723 [WEAK]
# #####  Correlation between num_comments and num_shares: Coefficient: 0.640637 [MODERATE]
# ##### The correlation between num_reactions and both num_comments and num_shares is positive and weak.
# ##### The correlation between num_comments and num_shares is positive and moderate.
# ##### In conclusion, while all three engagement metrics tend to move in the same direction (positive correlations), the strength of these relationships varies. Comments and shares appear to be more closely linked than reactions are to either of them

# %%
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='plasma', fmt=".2f")
plt.title('Correlation Matrix of Engagement Metrics')
plt.show()

# %% [markdown]
# ### QUESTION 3
# #### Use the columns status_type, num_reactions, num_comments, num_shares, num_likes, num_loves, num_wows, num_hahas, num_sads, and num_angrys to train a K-Means clustering model on the Facebook Live Sellers dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   status_id            7050 non-null   int64
#  1   status_type          7050 non-null   object
#  2   status_published     7050 non-null   datetime64[ns]
#  3   num_reactions        7050 non-null   int64
#  4   num_comments         7050 non-null   int64
#  5   num_shares           7050 non-null   int64
#  6   num_likes            7050 non-null   int64
#  7   num_loves            7050 non-null   int64
#  8   num_wows             7050 non-null   int64
#  9   num_hahas            7050 non-null   int64
#  10  num_sads             7050 non-null   int64
#  11  num_angrys           7050 non-null   int64
#  12  publish_hour         7050 non-null   int32
#  13  publish_day_of_week  7050 non-null   int32
#  14  publish_month        7050 non-null   int32
# ...

# %%
# Select the columns for clustering
clustering_features = ['status_type', 'num_reactions', 'num_comments', 'num_shares',
                       'num_likes', 'num_loves', 'num_wows', 'num_hahas', 'num_sads', 'num_angrys']
cluster_data = df[clustering_features].copy()

# %%
cluster_data.head()
# Out:
#   status_type  num_reactions  num_comments  num_shares  num_likes  num_loves  \
# 0       video            529           512         262        432         92
# 1       photo            150             0           0        150          0
# 2       video            227           236          57        204         21
# 3       photo            111             0           0        111          0
# 4       photo            213             0           0        204          9
#
#    num_wows  num_hahas  num_sads  num_angrys
# 0         3          1         1           0
# 1         0          0         0           0
# 2         1          1         0           0
# 3         0          0         0           0
# 4         0          0         0           0

# %%
cluster_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status_type    7050 non-null   object
#  1   num_reactions  7050 non-null   int64
#  2   num_comments   7050 non-null   int64
#  3   num_shares     7050 non-null   int64
#  4   num_likes      7050 non-null   int64
#  5   num_loves      7050 non-null   int64
#  6   num_wows       7050 non-null   int64
#  7   num_hahas      7050 non-null   int64
#  8   num_sads       7050 non-null   int64
#  9   num_angrys     7050 non-null   int64
# dtypes: int64(9), object(1)
# memory usage: 550.9+ KB

# %%
cluster_data['status_type'].unique()
# Out:
# array(['video', 'photo', 'link', 'status'], dtype=object)

# %%
#using ONE HOT ENCODER FOR THE status_type column
cluster_data = pd.get_dummies(cluster_data ,columns=['status_type'],drop_first=True)
cluster_data.head()
# Out:
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0            529           512         262        432         92         3
# 1            150             0           0        150          0         0
# 2            227           236          57        204         21         1
# 3            111             0           0        111          0         0
# 4            213             0           0        204          9         0
#
#    num_hahas  num_sads  num_angrys  status_type_photo  status_type_status  \
# 0          1         1           0              False               False
# 1          0         0           0               True               False
# 2          1         0           0              False               False
# 3          0         0           0               True               False
# 4          0         0           0               True               False
#
#    status_type_video
# 0               True
# 1              False
# ...

# %%
cluster_data.head()
# Out:
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0            529           512         262        432         92         3
# 1            150             0           0        150          0         0
# 2            227           236          57        204         21         1
# 3            111             0           0        111          0         0
# 4            213             0           0        204          9         0
#
#    num_hahas  num_sads  num_angrys  status_type_photo  status_type_status  \
# 0          1         1           0              False               False
# 1          0         0           0               True               False
# 2          1         0           0              False               False
# 3          0         0           0               True               False
# 4          0         0           0               True               False
#
#    status_type_video
# 0               True
# 1              False
# ...

# %%
cluster_data.shape
# Out:
# (7050, 12)

# %%
from sklearn.preprocessing import StandardScaler

# Identify numerical columns to scale (all columns after one-hot encoding are numerical)
numerical_cols_for_scaling = cluster_data.columns

#initialize the StandardScaler
scaler = StandardScaler()

#Fit the scaler to the data and then transform it 
cluster_data_scaled = scaler.fit_transform(cluster_data)

#convert the scaled data back to pandas dataframe for easier inspection
cluster_data_scaled_df=pd.DataFrame(cluster_data_scaled , columns=numerical_cols_for_scaling)

# %%
cluster_data_scaled_df.head()
# Out:
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0       0.646104      0.323350    1.686879   0.482727   1.983266  0.196196
# 1      -0.173192     -0.252206   -0.304144  -0.144720  -0.318454 -0.147879
# 2      -0.006738      0.013089    0.129017  -0.024571   0.206938 -0.033187
# 3      -0.257499     -0.252206   -0.304144  -0.231495  -0.318454 -0.147879
# 4      -0.037003     -0.252206   -0.304144  -0.024571  -0.093286 -0.147879
#
#    num_hahas  num_sads  num_angrys  status_type_photo  status_type_status  \
# 0   0.076713  0.473570   -0.155748          -1.245993           -0.233666
# 1  -0.176010 -0.152587   -0.155748           0.802573           -0.233666
# 2   0.076713 -0.152587   -0.155748          -1.245993           -0.233666
# 3  -0.176010 -0.152587   -0.155748           0.802573           -0.233666
# 4  -0.176010 -0.152587   -0.155748           0.802573           -0.233666
#
#    status_type_video
# 0           1.421466
# 1          -0.703499
# ...

# %%
from sklearn.cluster import KMeans

# %%
n_cluster=3
kmeans = KMeans(n_clusters = n_cluster , random_state=42,n_init=10)
kmeans.fit(cluster_data_scaled)
cluster_labels = kmeans.labels_

# %%
df['cluster']=cluster_labels

# %%
from sklearn.cluster import KMeans

# Initialize the K-Means model with a chosen number of clusters (let's start with 3)
n_clusters = 3
kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10) # Added n_init for future warning

# Fit the K-Means model to the scaled data
kmeans.fit(cluster_data_scaled)

# Get the cluster labels assigned to each data point
cluster_labels = kmeans.labels_

# Add the cluster labels back to the original DataFrame for analysis
df['cluster'] = cluster_labels

# Display the count of data points in each cluster
print(f"\nDistribution of data points across {n_clusters} clusters:")
print(df['cluster'].value_counts())

# Display the cluster centers (in the scaled feature space)
print("\nCluster centers (scaled data):")
print(kmeans.cluster_centers_)
# Out:
# Distribution of data points across 3 clusters:
# cluster
# 1    4320
# 2    2506
# 0     224
# Name: count, dtype: int64
#
# Cluster centers (scaled data):
# [[ 1.45237127e+00  3.58130625e+00  3.84301769e+00  1.08298685e+00
#    3.78371963e+00  2.19510719e+00  2.58363410e+00  1.75942920e+00
#    2.35662469e+00 -1.11795750e+00 -2.33666109e-01  1.28865567e+00]
#  [-1.12329459e-01 -2.37226878e-01 -2.87673914e-01 -8.72985046e-02
#   -2.83069145e-01 -7.23471242e-02 -1.38042921e-01 -9.14207000e-02
#   -1.24215395e-01  7.80759391e-01 -2.33666109e-01 -7.03499070e-01]
#  [ 6.38196725e-02  8.88298132e-02  1.52400378e-01  5.36873443e-02
#    1.49762773e-01 -7.14941877e-02  7.02768619e-03  3.29323331e-04
#    3.48227201e-03 -1.24599285e+00  4.23694652e-01  1.09754873e+00]]

# %% [markdown]
# #### Cluster 1 is the largest, containing 4320 data points.
# #### Cluster 2 is the second largest, with 2506 data points.
# #### Cluster 0 is significantly smaller, containing only 224 data points.

# %% [markdown]
#  Based on the steps we took, this order should be:
#
# num_reactions ,
# num_comments ,
# num_shares ,
# num_likes ,
# num_loves ,
# num_wows ,
# num_hahas ,
# num_sads ,
# num_angrys ,
# status_type_ link ,
# status_type_photo ,
# status_type_status ,
# status_type_video

# %% [markdown]
# ##### Cluster 0: [ 1.45, 3.58, 3.84, 1.08, 3.78, 2.20, 2.58, 1.76, 2.36, -1.18, -0.23, 1.29]
# ##### High Engagement: This cluster has significantly positive values for num_reactions, num_comments, num_shares, num_likes, num_loves, num_wows, num_hahas, and num_sads. This suggests posts in this cluster tend to have very high engagement across all these metrics.

# %% [markdown]
# ##### Cluster 1: [-0.11, -0.24, -0.29, -0.09, -0.28, -0.07, -0.14, -0.09, -0.12, 0.78, -0.23, -0.70]
#
# ##### Below Average Engagement: This cluster has slightly negative values for most of the engagement metrics, indicating below-average reactions, comments, shares, and individual reactions compared to the overall dataset.

# %% [markdown]
# ##### Cluster 2: [ 0.06, 0.09, 0.15, 0.05, 0.15, -0.07, 0.01, 0.00, 0.00, -1.25, 0.42, 1.10]
#
# ##### Around Average Engagement: The engagement metrics in this cluster are close to zero, indicating near-average levels of reactions, comments, and shares. Some individual reactions are slightly positive.

# %% [markdown]
# ### Question 4: Use the elbow method to find the optimum number of clusters.

# %%
range_of_clusters = range(1, 11)
wcss = []

for i in range_of_clusters:
    # Initialize and fit the K-Means model for the current number of clusters
    kmeans = KMeans(n_clusters=i, random_state=42, n_init=10)
    kmeans.fit(cluster_data_scaled)

    # Append the inertia (WCSS) to our list
    wcss.append(kmeans.inertia_)

# Print the WCSS values for each number of clusters
print("\nWCSS values for different numbers of clusters:")
print(wcss)
# Out:
# WCSS values for different numbers of clusters:
# [84599.99999999991, 68276.6775551093, 55527.54075341273, 45920.78458099108, 38788.899945011406, 33376.952013154216, 29534.344428735894, 26301.363538463534, 23650.872600722614, 20712.982678083008]

# %%
# Plot the elbow curve
plt.figure(figsize=(10, 6))
plt.plot(range_of_clusters, wcss, marker='o', linestyle='-')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Within-Cluster Sum of Squared Errors (WCSS)')
plt.grid(True)
plt.xticks(range_of_clusters)
plt.show()

#The elbow method suggests that the optimal number of clusters for this dataset is likely 3 or 4. 
#Choosing either of these numbers would represent a good balance between minimizing the 
#within-cluster variance and avoiding overfitting by having too many clusters.

# %% [markdown]
# #### Question 5 : Count the different types of posts in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   status_id            7050 non-null   int64
#  1   status_type          7050 non-null   object
#  2   status_published     7050 non-null   datetime64[ns]
#  3   num_reactions        7050 non-null   int64
#  4   num_comments         7050 non-null   int64
#  5   num_shares           7050 non-null   int64
#  6   num_likes            7050 non-null   int64
#  7   num_loves            7050 non-null   int64
#  8   num_wows             7050 non-null   int64
#  9   num_hahas            7050 non-null   int64
#  10  num_sads             7050 non-null   int64
#  11  num_angrys           7050 non-null   int64
#  12  publish_hour         7050 non-null   int32
#  13  publish_day_of_week  7050 non-null   int32
#  14  publish_month        7050 non-null   int32
# ...

# %%
a = df['status_type'].value_counts()

# %%
post_type_counts = a
print(post_type_counts)
# Out:
# status_type
# photo     4288
# video     2334
# status     365
# link        63
# Name: count, dtype: int64

# %% [markdown]
# #### Question 6: What is the average value of
# #### num_reaction, num_comments, num_shares for each post type?

# %%
# Group the DataFrame by 'status_type'
grouped_by_type = df.groupby('status_type')

# Calculate the mean of 'num_reactions', 'num_comments', and 'num_shares' for each group
average_engagement_by_type = grouped_by_type[['num_reactions', 'num_comments', 'num_shares']].mean()

# Print the resulting averages
print("\nAverage engagement metrics per post type:")
print(average_engagement_by_type)
# Out:
# Average engagement metrics per post type:
#              num_reactions  num_comments  num_shares
# status_type
# link            370.142857      5.698413    4.396825
# photo           181.290345     15.993470    2.553871
# status          438.783562     36.238356    2.558904
# video           283.409597    642.478149  115.679949

# %% [markdown]
# ##### Link:
#
# ##### Has a relatively high average number of reactions (370.14).
# ##### Has the lowest average number of comments (5.70).
# ##### Has a relatively low average number of shares (4.40).
# ##### Interpretation: Link posts tend to get a good amount of initial reaction but don't spark much discussion or sharing compared to other types.
#
# ##### Photo:
#
# ##### Has the lowest average number of reactions (181.29).
# ##### Has a moderate average number of comments (15.99).
# ##### Has the lowest average number of shares (2.55).
# ##### Interpretation: Photo posts might be quickly consumed and reacted to with a like, but they don't necessarily drive extensive commenting or sharing in this dataset.
#
# ##### Status:
#
# ##### Has the highest average number of reactions (438.78).
# ##### Has a good average number of comments (36.24), second only to videos.
# ##### Has a very low average number of shares (2.56), similar to photos.
# ##### Interpretation: Simple text-based status updates seem to be very effective at generating reactions and a significant amount of comments, but they are not shared much.
#
# ##### Video:
#
# ##### Has an average number of reactions (283.41) that falls in the middle.
# ##### Has by far the highest average number of comments (642.48).
# ##### Has by far the highest average number of shares (115.68).
# ##### Interpretation: Video posts, while not leading in reactions, are incredibly effective at driving conversations (comments) and encouraging users to share the content with their networks.
